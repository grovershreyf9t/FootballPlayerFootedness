# %% [markdown]
# **2. Pre-processing the Wyscout data**
#
# **A) The following tasks are taken into account in this notebook:**
#
# 1. The Wyscout data jsons (Competitions, Matches, Events and Players) are processed and stored in dataframes.
#
# 2. The defence formation data (as obtained from 1_PLparser.ipynb) is merged with the Wyscout data, in such a way that each row of the new dataframe denotes a team for a particular match.
#
# 3. The resulting dataframe is further processed to normalise team and player names
#
# 4. Footedness and event tags information is added to the dataframe
#
# 5. Event coordinates are converted to the scale of x belongs to [0,104] and y belongs to [0,68]
#
# **B) The following were the resulting pickle files of this notebook:**
#
# **events_v2.pkl** - processed Wyscout events data with scaled coordinates
#
# **match+def_lineup+footedness_ver2.pkl** - defence formation data with each row denoting a team for a particular match

# %% [markdown]
# **Note:**
#
# 1. All experiments have been run on Premier League data only
#
# 2. We understand that the role of center backs changes with change in number of players in the defence lineups.  For simplicity, our analysis includes two categories - lineups with four defenders and lineups with other than four defenders. The following is the formation nomenclature:
#
#
#     a. For a defence lineup with 4 players:
#             i. LB - Left Back
#             ii. L_CB - Left Center Back
#             iii. R_CB - Right Center Back
#             iv. RB - Right Back
#
#
#     b. For a defence lineup with 3 or 5 players:
#             i. LWB - Left Wing Back (only for 5 defenders)
#             ii. LCB - Left Center Back (for both 3 and 5 defenders)
#             iii. CB - Center Back (for both 3 and 5 defenders)
#             iv. RCB - Right Center Back (for both 3 and 5 defenders)
#             v. RB - Right Wing Back (only for 5 defenders)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime
import warnings
import json
import operator
from matplotlib.ticker import FuncFormatter
from matplotlib.patches import Ellipse
import base64
from collections import defaultdict
import sys,os
import math
import random
import matplotlib.pylab as pyl
import itertools
import pickle
import swifter
import warnings
from unidecode import unidecode
from itertools import chain
from multiprocessing import  Pool

warnings.filterwarnings('ignore')

# %%
# pd.set_option('max_colwidth', 999)

# %%
pd.set_option('display.max_columns', 1000)
pd.set_option("display.max_rows", 3000)
warnings.filterwarnings('ignore')

# %% [markdown]
# # Competitions

# %% [markdown]
# - area: it denotes the geographic area associated with the league as a sub-document, using the ISO 3166-1 specification (https://www.iso.org/iso-3166-country-codes.html);
# - format: the format of the competition. All competitions for clubs have value "Domestic league". The competitions for national teams have value "International cup";
# - name: the official name of the competition (e.g., Italian first division, Spanish first division, World Cup, etc.);
# - type: the typology of the competition. It is "club" for the competitions for clubs and "international" for the competitions for national teams (World Cup 2018, European Cup 2016);
# - wyId: the unique identifier of the competition, assigned by Wyscout.

# %%
comps = pd.read_json('../data_top5/competitions/competitions.json')
comps = pd.DataFrame(comps)
comps
# Out:
#                      name  wyId             format  \
# 0  Italian first division   524    Domestic league
# 1  English first division   364    Domestic league
# 2  Spanish first division   795    Domestic league
# 3   French first division   412    Domestic league
# 4   German first division   426    Domestic league
# 5   European Championship   102  International cup
# 6               World Cup    28  International cup
#
#                                                 area           type
# 0  {'name': 'Italy', 'id': '380', 'alpha3code': '...           club
# 1  {'name': 'England', 'id': '0', 'alpha3code': '...           club
# 2  {'name': 'Spain', 'id': '724', 'alpha3code': '...           club
# 3  {'name': 'France', 'id': '250', 'alpha3code': ...           club
# 4  {'name': 'Germany', 'id': '276', 'alpha3code':...           club
# 5  {'name': '', 'id': 0, 'alpha3code': 'XEU', 'al...  international
# 6  {'name': '', 'id': 0, 'alpha3code': 'XWO', 'al...  international

# %% [markdown]
# # Matches

# %% [markdown]
# - competitionId: the identifier of the competition to which the match belongs to. It is a integer and refers to the field "wyId" of the competition document;
# - date and dateutc: the former specifies date and time when the match starts in explicit format (e.g., May 20, 2018 at 8:45:00 PM GMT+2), the latter contains the same information but in the compact format YYYY-MM-DD hh:mm:ss;
# - duration: the duration of the match. It can be "Regular" (matches of regular duration of 90 minutes + stoppage time), "ExtraTime" (matches with supplementary times, as it may happen for matches in continental or international competitions), or "Penalities" (matches which end at penalty kicks, as it may happen for continental or international competitions);
# - gameweek: the week of the league, starting from the beginning of the league;
# - label: contains the name of the two clubs and the result of the match (e.g., "Lazio - Internazionale, 2 - 3");
# - roundID: indicates the match-day of the competition to which the match belongs to. During a competition for soccer clubs, each of the participating clubs plays against each of the other clubs twice, once at home and once away. The matches are organized in match-days: all the matches in match-day i are played before the matches in match-day i + 1, even tough some matches can be anticipated or postponed to facilitate players and clubs participating in Continental or Intercontinental competitions. During a competition for national teams, the "roundID" indicates the stage of the competition (eliminatory round, round of 16, quarter finals, semifinals, final);
# - seasonId: indicates the season of the match;
# - status: it can be "Played" (the match has officially finished), "Cancelled" (the match has been canceled for some reason), "Postponed" (the match has been postponed and no new date and time is available yet) or "Suspended" (the match has been suspended and no new date and time is available yet);
# - venue: the stadium where the match was held (e.g., "Stadio Olimpico");
# - winner: the identifier of the team which won the game, or 0 if the match ended with a draw;
# - wyId: the identifier of the match, assigned by Wyscout;
# - teamsData: it contains several subfields describing information about each team that is playing that match: such as lineup, bench composition, list of substitutions, coach and scores:
# - hasFormation: it has value 0 if no formation (lineups and benches) is present, and 1 otherwise;
# - score: the number of goals scored by the team during the match (not counting penalties);
# - scoreET: the number of goals scored by the team during the match, including the extra time (not counting penalties);
# - scoreHT: the number of goals scored by the team during the first half of the match;
# - scoreP: the total number of goals scored by the team after the penalties;
# - side: the team side in the match (it can be "home" or "away");
# - teamId: the identifier of the team;
# - coachId: the identifier of the team's coach;
# - bench: the list of the team's players that started the match in the bench and some basic statistics about their performance during the match (goals, own goals, cards);
# - lineup: the list of the team's players in the starting lineup and some basic statistics about their performance during the match (goals, own goals, cards);
# - substitutions: the list of team's substitutions during the match, describing the players involved and the minute of the substitution.

# %%
country = ['England', 'France', 'Germany', 'Italy', 'Spain']
matches1 = pd.DataFrame()

for i in country:
    path = '../data_top5/matches/matches_'+i+'.json'
    matches = pd.read_json(path)
    matches = pd.DataFrame(matches)
    matches1 = pd.concat([matches, matches1]) 

matches1.reset_index(drop=True, inplace=True)
print(matches1.shape)
# Out:
# (1826, 14)

# %% [markdown]
# Sample 'TeamsData' row entry:

# %% [markdown]
# # Events

# %% [markdown]
# - eventId: the identifier of the event's type. Each eventId is associated with an event name (see next point);
# - eventName: tteamIdhe name of the event's type. There are seven types of events: pass, foul, shot, duel, free kick, offside and touch;
# - subEventId: the identifier of the subevent's type. Each subEventId is associated with a subevent name (see next point);
# - subEventName: the name of the subevent's type. Each event type is associated with a different set of subevent types;
# - tags: a list of event tags, each one describes additional information about the event (e.g., accurate). Each event type is associated with a different set of tags;
# - eventSec: the time when the event occurs (in seconds since the beginning of the current half of the match);
# - id: a unique identifier of the event;
# - matchId: the identifier of the match the event refers to. The identifier refers to the field "wyId" in the match dataset;
# - matchPeriod: the period of the match. It can be "1H" (first half of the match), "2H" (second half of the match), "E1" (first extra time), "E2" (second extra time) or "P" (penalties time);
# - playerId: the identifier of the player who generated the event. The identifier refers to the field "wyId" in a player dataset;
# - positions: the origin and destination positions associated with the event. Each position is a pair of coordinates (x, y). The x and y coordinates are always in the range [0, 100] and indicate the percentage of the field from the perspective of the attacking team. In particular, the value of the x coordinate indicates the event's nearness (in percentage) to the opponent's goal, while the value of the y coordinates indicates the event's nearness (in percentage) to the right side of the field;
# - teamId: the identifier of the player's team. The identifier refers to the field "wyId" in the team dataset.

# %%
events1 = pd.DataFrame()

for i in country:
    path = '../data_top5/events/events_'+i+'.json'
    events = pd.read_json(path)
    events = pd.DataFrame(events)
    events1 = pd.concat([events, events1]) 

events1.reset_index(drop=True, inplace=True)
print(events1.shape)
# Out:
# (3071395, 12)

# %%
print(len(events1.matchId.unique()))
print(matches1.shape)
# Out:
# 1826
# (1826, 14)

# %%
events1.matchId.value_counts().mean()
# Out:
# 1682.0345016429353

# %% [markdown]
# Approximately, every 3.19 seconds, an event activity is registered

# %% [markdown]
# # Player

# %% [markdown]
# - birthArea: geographic information about the player's birth area;
# - birthDate: the birth date of the player, in the format "YYYY-MM-DD";
# - currentNationalTeamId: the identifier of the national team where the players currently plays;
# - currentTeamId: the identifier of the team where the player plays for. The identifier refers to the field "wyId" in a team document;
# - firstName: the first name of the player;
# - lastName: the last name of the player;
# - foot: the preferred foot of the player;
# - height: the height of the player (in centimeters);
# - middleName: the middle name (if any) of the player;
# - passportArea: the geographic area associated with the player's current passport;
# - role: the main role of the player. It is a subdocument containing the role's name and two abbreviations of it;
# - shortName2: the short name of the player;
# - weight: the weight of the player (in kilograms);
# - wyId: the identifier of the player, assigned by Wyscout.

# %%
players = pd.read_json('../data_top5/players/players.json')
players = pd.DataFrame(players)
print(players.shape)
display(players)
# Out:
# (3603, 14)
#                                            passportArea  weight  \
# 0     {'name': 'Turkey', 'id': '792', 'alpha3code': ...      78
# 1     {'name': 'Senegal', 'id': '686', 'alpha3code':...      73
# 2     {'name': 'France', 'id': '250', 'alpha3code': ...      72
# 3     {'name': 'Senegal', 'id': '686', 'alpha3code':...      82
# 4     {'name': 'France', 'id': '250', 'alpha3code': ...      84
# ...                                                 ...     ...
# 3598  {'name': 'Tunisia', 'id': 788, 'alpha3code': '...      72
# 3599  {'name': 'Peru', 'id': 604, 'alpha3code': 'PER...      76
# 3600  {'name': 'Peru', 'id': 604, 'alpha3code': 'PER...      78
# 3601  {'name': 'Morocco', 'id': 504, 'alpha3code': '...      70
# 3602  {'name': 'Panama', 'id': 591, 'alpha3code': 'P...       0
#
#               firstName middleName             lastName currentTeamId  \
# 0                 Harun                           Tekin          4502
# 1                Malang                            Sarr          3775
# 2                  Over                        Mandanda          3772
# 3     Alfred John Momar                         N'Diaye           683
# 4              Ibrahima                     Konat\u00e9          2975
# ...                 ...        ...                  ...           ...
# 3598                Ali                    Ma\u00e2loul         16041
# 3599     Carlos Alberto             C\u00e1ceda Oyaguez         15591
# 3600  Miguel Gianpierre                   Araujo Blanco         12072
# 3601         Ahmed Reda                       Tagnaouti         16183
# 3602            Ricardo                   Guardia Avila         62943
#
#        birthDate  height                                               role  \
# 0     1989-06-17     187  {'code2': 'GK', 'code3': 'GKP', 'name': 'Goalk...
# 1     1999-01-23     182  {'code2': 'DF', 'code3': 'DEF', 'name': 'Defen...
# 2     1998-10-26     176  {'code2': 'GK', 'code3': 'GKP', 'name': 'Goalk...
# 3     1990-03-06     187  {'code2': 'MD', 'code3': 'MID', 'name': 'Midfi...
# 4     1999-05-25     192  {'code2': 'DF', 'code3': 'DEF', 'name': 'Defen...
# ...          ...     ...                                                ...
# 3598  1990-01-01     175  {'code2': 'DF', 'code3': 'DEF', 'name': 'Defen...
# 3599  1991-09-27     183  {'code2': 'GK', 'code3': 'GKP', 'name': 'Goalk...
# 3600  1994-10-24     179  {'code2': 'DF', 'code3': 'DEF', 'name': 'Defen...
# 3601  1996-04-05     182  {'code2': 'GK', 'code3': 'GKP', 'name': 'Goalk...
# 3602  1997-02-04       0  {'code2': 'MD', 'code3': 'MID', 'name': 'Midfi...
#
#                                               birthArea    wyId   foot  \
# 0     {'name': 'Turkey', 'id': '792', 'alpha3code': ...   32777  right
# 1     {'name': 'France', 'id': '250', 'alpha3code': ...  393228   left
# 2     {'name': 'France', 'id': '250', 'alpha3code': ...  393230
# 3     {'name': 'France', 'id': '250', 'alpha3code': ...   32793  right
# 4     {'name': 'France', 'id': '250', 'alpha3code': ...  393247  right
# ...                                                 ...     ...    ...
# 3598  {'name': 'Tunisia', 'id': 788, 'alpha3code': '...  120839   left
# 3599  {'name': 'Peru', 'id': 604, 'alpha3code': 'PER...  114736  right
# 3600  {'name': 'Peru', 'id': 604, 'alpha3code': 'PER...  114908  right
# 3601  {'name': 'Morocco', 'id': 504, 'alpha3code': '...  285583  right
# 3602  {'name': 'Panama', 'id': 591, 'alpha3code': 'P...  361536   left
#
#             shortName currentNationalTeamId
# 0            H. Tekin                  4687
# 1             M. Sarr                  4423
# 2         O. Mandanda                  null
# 3          A. N'Diaye                 19314
# 4      I. Konat\u00e9                  null
# ...               ...                   ...
# 3598  A. Ma\u00e2loul                  null
# 3599   C. C\u00e1ceda                  null
# 3600        M. Araujo                  null
# 3601     A. Tagnaouti                  null
# 3602         R. Avila                  null
#
# [3603 rows x 14 columns]

# %% [markdown]
# # Events + Player DF

# %%
events_com = pd.merge(right=players, left=events1, right_on='wyId', left_on='playerId', how='left')
print(events_com.shape)
# Out:
# (3071395, 26)

# %%
#Those playerIds from df events that dont have an entry in df players
noplayer = events_com[events_com['firstName'].isna().values]
noplayer
# Out:
#          eventId           subEventName  \
# 24             5  Ball out of the field
# 29             5  Ball out of the field
# 32             5  Ball out of the field
# 57             5  Ball out of the field
# 71             5  Ball out of the field
# ...          ...                    ...
# 3071325        5  Ball out of the field
# 3071346        3              Free Kick
# 3071362        1  Ground defending duel
# 3071385        3              Free Kick
# 3071390        5  Ball out of the field
#
#                                              tags  playerId  \
# 24                                             []         0
# 29                                             []         0
# 32                                             []         0
# 57                                             []         0
# 71                                             []         0
# ...                                           ...       ...
# 3071325                                        []         0
# 3071346                            [{'id': 1801}]         0
# 3071362  [{'id': 502}, {'id': 701}, {'id': 1802}]         0
# 3071385                            [{'id': 1801}]         0
# 3071390                                        []         0
#
#                                            positions  matchId     eventName  \
# 24         [{'y': 35, 'x': 0}, {'y': 100, 'x': 100}]  2565548  Interruption
# 29         [{'y': 19, 'x': 7}, {'y': 100, 'x': 100}]  2565548  Interruption
# 32             [{'y': 0, 'x': 61}, {'y': 0, 'x': 0}]  2565548  Interruption
# 57         [{'y': 0, 'x': 46}, {'y': 100, 'x': 100}]  2565548  Interruption
# 71         [{'y': 41, 'x': 0}, {'y': 100, 'x': 100}]  2565548  Interruption
# ...                                              ...      ...           ...
# 3071325  [{'y': 100, 'x': 51}, {'y': 100, 'x': 100}]  2500098  Interruption
# 3071346     [{'y': 87, 'x': 40}, {'y': 80, 'x': 56}]  2500098     Free Kick
# 3071362       [{'y': 34, 'x': 7}, {'y': 28, 'x': 5}]  2500098          Duel
# 3071385     [{'y': 81, 'x': 70}, {'y': 70, 'x': 59}]  2500098     Free Kick
# 3071390    [{'y': 32, 'x': 0}, {'y': 100, 'x': 100}]  2500098  Interruption
#
#          teamId matchPeriod     eventSec subEventId         id passportArea  \
# 24          682          1H    83.100786         50  180864467          NaN
# 29          682          1H   119.589776         50  180864441          NaN
# 32          695          1H   139.970551         50  180865320          NaN
# 57          682          1H   243.077555         50  180864466          NaN
# 71          682          1H   301.181860         50  180864469          NaN
# ...         ...         ...          ...        ...        ...          ...
# 3071325    1623          2H  2589.146520         50  251596374          NaN
# 3071346    1623          2H  2665.580593         31  251596391          NaN
# 3071362    1623          2H  2712.941293         12  251596987          NaN
# 3071385    1633          2H  2780.300522         31  251596224          NaN
# 3071390    1623          2H  2796.732525         50  251596409          NaN
#
#          weight firstName middleName lastName currentTeamId birthDate  height  \
# 24          NaN       NaN        NaN      NaN           NaN       NaN     NaN
# 29          NaN       NaN        NaN      NaN           NaN       NaN     NaN
# 32          NaN       NaN        NaN      NaN           NaN       NaN     NaN
# 57          NaN       NaN        NaN      NaN           NaN       NaN     NaN
# 71          NaN       NaN        NaN      NaN           NaN       NaN     NaN
# ...         ...       ...        ...      ...           ...       ...     ...
# 3071325     NaN       NaN        NaN      NaN           NaN       NaN     NaN
# 3071346     NaN       NaN        NaN      NaN           NaN       NaN     NaN
# 3071362     NaN       NaN        NaN      NaN           NaN       NaN     NaN
# 3071385     NaN       NaN        NaN      NaN           NaN       NaN     NaN
# 3071390     NaN       NaN        NaN      NaN           NaN       NaN     NaN
#
#         role birthArea  wyId foot shortName currentNationalTeamId
# 24       NaN       NaN   NaN  NaN       NaN                   NaN
# 29       NaN       NaN   NaN  NaN       NaN                   NaN
# 32       NaN       NaN   NaN  NaN       NaN                   NaN
# 57       NaN       NaN   NaN  NaN       NaN                   NaN
# 71       NaN       NaN   NaN  NaN       NaN                   NaN
# ...      ...       ...   ...  ...       ...                   ...
# 3071325  NaN       NaN   NaN  NaN       NaN                   NaN
# 3071346  NaN       NaN   NaN  NaN       NaN                   NaN
# 3071362  NaN       NaN   NaN  NaN       NaN                   NaN
# 3071385  NaN       NaN   NaN  NaN       NaN                   NaN
# 3071390  NaN       NaN   NaN  NaN       NaN                   NaN
#
# [226038 rows x 26 columns]

# %%
noplayer.subEventName.value_counts()
# Out:
# Ball out of the field     129154
# Ground defending duel      29468
# Ground attacking duel      23047
# Ground loose ball duel     18365
# Air duel                   12320
# Free Kick                   9495
# Throw in                    2272
# Whistle                      913
# Foul                         335
# Touch                        255
# Goal kick                    193
# Corner                       131
#                               28
# Simple pass                   18
# Free kick cross               11
# Launch                         7
# Hand foul                      7
# Clearance                      5
# Cross                          3
# Shot                           3
# Save attempt                   2
# Reflexes                       2
# Head pass                      1
# Out of game foul               1
# Smart pass                     1
# High pass                      1
# Name: subEventName, dtype: int64

# %% [markdown]
# These entries are the interruptions that dont need a player (mostly, rest are data collection anomalies)

# %%
events_com = events_com.dropna(subset=['firstName'])
events_com = events_com.reset_index(drop=True)

# %%
events_com.shape
# Out:
# (2845357, 26)

# %%
events_com.to_pickle('../data_top5/events/events_com.pkl')

# %% [markdown]
# # Extracting Player Position from Match Lineup

# %% [markdown]
# ## Extracting Defender Position

# %%
# sys.setrecursionlimit(10000)
defence = pd.read_pickle('../data_top5/matches/top_5_lineups.pkl')

# %%
defence.shape
# Out:
# (1826, 9)

# %%
defence
# Out:
#              tournament gameweek        date        home_team score  \
# 0        Premier League        1  2017-08-11          Arsenal   4–3
# 1        Premier League        1  2017-08-12          Watford   3–3
# 2        Premier League        1  2017-08-12        West Brom   1–0
# 3        Premier League        1  2017-08-12          Everton   1–0
# 4        Premier League        1  2017-08-12      Southampton   0–0
# 5        Premier League        1  2017-08-12          Chelsea   2–3
# 6        Premier League        1  2017-08-12   Crystal Palace   0–3
# 7        Premier League        1  2017-08-12         Brighton   0–2
# 8        Premier League        1  2017-08-13    Newcastle Utd   0–2
# 9        Premier League        1  2017-08-13   Manchester Utd   4–0
# 10       Premier League        2  2017-08-19     Swansea City   0–4
# 11       Premier League        2  2017-08-19      Southampton   3–2
# 12       Premier League        2  2017-08-19   Leicester City   2–0
# 13       Premier League        2  2017-08-19      Bournemouth   0–2
# 14       Premier League        2  2017-08-19          Burnley   0–1
# 15       Premier League        2  2017-08-19        Liverpool   1–0
# 16       Premier League        2  2017-08-19       Stoke City   1–0
# 17       Premier League        2  2017-08-20     Huddersfield   1–0
# 18       Premier League        2  2017-08-20        Tottenham   1–2
# 19       Premier League        2  2017-08-21  Manchester City   1–1
# 20       Premier League        3  2017-08-26      Bournemouth   1–2
# 21       Premier League        3  2017-08-26   Crystal Palace   0–2
# 22       Premier League        3  2017-08-26     Huddersfield   0–0
# 23       Premier League        3  2017-08-26          Watford   0–0
# 24       Premier League        3  2017-08-26    Newcastle Utd   3–0
# 25       Premier League        3  2017-08-26   Manchester Utd   2–0
# 26       Premier League        3  2017-08-27        West Brom   1–1
# 1577  [DaniloDAmbrosio, MilanSkriniar, Miranda, Davi...
# 1578  [AlessandroFlorenzi, FedericoFazio, JuanJesus,...
# 1579  [ChristianMaggio, VladChiriches, KalidouKoulib...
# 1580  [LorenzoDeSilvestri, NicolasNkoulou, NicolasBu...
# 1581  [VincentLaurini, GermanPezzella, DavideAstori,...
# 1582  [MarioSampirisi, ArlindAjeti, FedericoCeccherini]
# 1583  [LorenzoVenuti, BeratDjimsiti, AndreaCosta, Gi...
# 1584  [MicheleCremonesi, FrancescoVicari, FelipedalB...
# 1585  [MattiaDeSciglio, MedhiBenatia, GiorgioChielli...
# 1586       [RafaelToloi, MattiaCaldara, AndreaMasiello]
# 1587  [MateoMusacchio, LeonardoBonucci, AlessioRomag...
# 1588  [EdoardoGoldaniga, PaoloCannavaro, FrancescoAc...
# 1589    [FilippoRomagna, LucaCeppitelli, FabioPisacane]
# 1590  [FabrizioCacciatore, DarioDainelli, Alessandro...
# 1591                 [Bastos, StefandeVrij, StefanRadu]
# 1592   [GabrieleAngella, DaniloLarangeira, SamirSantos]
# 1593       [ArmandoIzzo, NicolasSpolli, ErvinZukanovic]
# 1594  [BartoszBereszynski, MatiasSilvestre, GianMarc...
# 1595  [DaniloDAmbrosio, MilanSkriniar, Miranda, Davi...
# 1596  [BrunoPeres, FedericoFazio, JuanJesus, Aleksan...
# 1597  [MartinCaceres, AlexFerrari, AntonioCaracciolo...
# 1598  [VincentLaurini, GermanPezzella, DavideAstori,...
# 1599            [LucaAntei, BeratDjimsiti, AndreaCosta]
# 1600  [MarioSampirisi, FedericoCeccherini, ArlindAje...
# 1601  [VasilisTorosidis, GiancarloGonzalez, FilipHel...
# 1602  [LorenzoDeSilvestri, NicolasNkoulou, NicolasBu...
# 1603       [RafaelToloi, MattiaCaldara, AndreaMasiello]
# 1604  [JensStrygerLarsen, DaniloLarangeira, BramNuyt...
# 1605  [ElseidHysaj, RaulAlbiol, KalidouKoulibaly, Ma...
# 1606    [FilippoRomagna, MarcoAndreolli, FabioPisacane]
# 1607  [DavideCalabria, LeonardoBonucci, AlessioRomag...
# 1608  [MattiaDeSciglio, MedhiBenatia, AndreaBarzagli...
# 1609  [FabrizioCacciatore, DarioDainelli, Alessandro...
# 1610       [ArmandoIzzo, NicolasSpolli, ErvinZukanovic]
# 1611  [PolLirola, EdoardoGoldaniga, FrancescoAcerbi,...
# 1612  [BartoszSalamon, FrancescoVicari, MicheleCremo...
# 1613                 [Bastos, StefandeVrij, StefanRadu]
# 1614  [IbrahimaMbaye, GiancarloGonzalez, FilipHeland...
# 1615        [NikolaMilenkovic, VitorHugo, DavideAstori]
# 1616  [MarioSampirisi, ArlindAjeti, FedericoCeccheri...
# 1617         [BeratDjimsiti, FabioLucioni, AndreaCosta]
# 1618  [LorenzoDeSilvestri, NicolasNkoulou, Lyanco, C...
# 1619  [BartoszBereszynski, MatiasSilvestre, GianMarc...
# 1620  [JoaoCancelo, MilanSkriniar, Miranda, DaniloDA...
# 1621  [AlexFerrari, ThomasHeurtaux, AntonioCaracciol...
# 1622       [RafaelToloi, MattiaCaldara, AndreaMasiello]
# 1623  [AlessandroFlorenzi, KostasManolas, FedericoFa...
# 1624  [ChristianMaggio, RaulAlbiol, KalidouKoulibaly...
# 1625  [DavideCalabria, LeonardoBonucci, AlessioRomag...
# 1626  [JensStrygerLarsen, DaniloLarangeira, SamirSan...
# 1627   [BartoszSalamon, FrancescoVicari, FelipedalBelo]
# 1628   [FilippoRomagna, LucaCeppitelli, MarcoAndreolli]
# 1629       [ArmandoIzzo, NicolasSpolli, ErvinZukanovic]
# 1630  [FabrizioCacciatore, NenadTomovic, BostjanCesa...
# 1631  [PolLirola, PaoloCannavaro, FrancescoAcerbi, F...
# 1632                 [Bastos, StefandeVrij, StefanRadu]
# 1633  [StephanLichtsteiner, MedhiBenatia, GiorgioChi...
# 1634      [BramNuytinck, DaniloLarangeira, SamirSantos]
# 1635  [JoaoCancelo, AndreaRanocchia, MilanSkriniar, ...
# 1636  [EmilKrafth, GiancarloGonzalez, FilipHelander,...
# 1637  [JacopoSala, MatiasSilvestre, GianMarcoFerrari...
# 1638  [MarioSampirisi, ArlindAjeti, FedericoCeccheri...
# 1639                [Wallace, StefandeVrij, StefanRadu]
# 1640  [AlexFerrari, ThomasHeurtaux, AntonioCaracciol...
# 1641  [PolLirola, EdoardoGoldaniga, FrancescoAcerbi,...
# 1642     [RafaelToloi, MattiaCaldara, JoseLuisPalomino]
# 1643  [AndreaBarzagli, MedhiBenatia, GiorgioChiellin...
# 1644  [ElseidHysaj, RaulAlbiol, KalidouKoulibaly, Ma...
# 1645  [LorenzoDeSilvestri, NicolasNkoulou, NicolasBu...
# 1646    [JeanClaudeBillong, BeratDjimsiti, AndreaCosta]
# 1647  [MarioSampirisi, FedericoCeccherini, MarcoCapu...
# 1648  [FabrizioCacciatore, MattiaBani, NenadTomovic,...
# 1649     [ThiagoCionek, FrancescoVicari, FelipedalBelo]
# 1650        [VincentLaurini, GermanPezzella, VitorHugo]
# 1651  [DavideCalabria, LeonardoBonucci, AlessioRomag...
# 1652  [AlessandroFlorenzi, KostasManolas, FedericoFa...
# 1653       [ArmandoIzzo, NicolasSpolli, LucaRossettini]
# 1654      [BramNuytinck, DaniloLarangeira, SamirSantos]
# 1655  [AlessandroFlorenzi, KostasManolas, FedericoFa...
# 1656    [RafaelToloi, JoseLuisPalomino, AndreaMasiello]
# 1657  [MattiaDeSciglio, MedhiBenatia, AndreaBarzagli...
# 1658  [DaniloDAmbrosio, MilanSkriniar, Miranda, Joao...
# 1659      [BramNuytinck, DaniloLarangeira, SamirSantos]
# 1660  [AlexFerrari, AntonioCaracciolo, JagosVukovic,...
# 1661  [IbrahimaMbaye, SebastienDeMaio, FilipHelander...
# 1662  [LorenzoVenuti, JeanClaudeBillong, BeratDjimsi...
# 1663     [FabioPisacane, LucaCeppitelli, LeandroCastan]
# 1664                 [Bastos, StefandeVrij, StefanRadu]
# 1665  [BartoszBereszynski, MatiasSilvestre, GianMarc...
# 1666  [LorenzoDeSilvestri, NicolasNkoulou, NicolasBu...
# 1667  [DavideFaraoni, FedericoCeccherini, MarcoCapua...
# 1668  [AlessandroFlorenzi, KostasManolas, FedericoFa...
# 1669     [ThiagoCionek, FrancescoVicari, FelipedalBelo]
# 1670  [IgnazioAbate, LeonardoBonucci, AlessioRomagno...
# 1671  [VincentLaurini, NikolaMilenkovic, DavideAstor...
# 1672  [PolLirola, MauricioLemos, FrancescoAcerbi, Fe...
# 1673   [MattiaBani, DarioDainelli, AlessandroGamberini]
# 1674  [ElseidHysaj, RaulAlbiol, KalidouKoulibaly, Ma...
# 1675   [DavideBiraschi, LucaRossettini, ErvinZukanovic]
# 1676  [StephanLichtsteiner, MedhiBenatia, GiorgioChi...
# 1677  [IgnazioAbate, LeonardoBonucci, AlessioRomagno...
# 1678    [RafaelToloi, JoseLuisPalomino, AndreaMasiello]
# 1679                [Wallace, StefandeVrij, StefanRadu]
# 1680    [MarcoAndreolli, LucaCeppitelli, LeandroCastan]
# 1681  [IbrahimaMbaye, GiancarloGonzalez, SebastienDe...
# 1682  [Romulo, AntonioCaracciolo, JagosVukovic, Moha...
# 1683     [JensStrygerLarsen, BramNuytinck, SamirSantos]
# 1684    [DavideBiraschi, NicolasSpolli, ErvinZukanovic]
# 1685  [LorenzoVenuti, BeratDjimsiti, AndreaCosta, Ga...
# 1686  [AlessandroFlorenzi, KostasManolas, FedericoFa...
# 1687    [MarcoAndreolli, LucaCeppitelli, LeandroCastan]
# 1688  [JoaoCancelo, AndreaRanocchia, MilanSkriniar, ...
# 1689  [MattiaDeSciglio, DanieleRugani, GiorgioChiell...
# 1690  [DavideFaraoni, FedericoCeccherini, MarcoCapua...
# 1691  [PolLirola, EdoardoGoldaniga, FrancescoAcerbi,...
# 1692   [BartoszSalamon, FrancescoVicari, FelipedalBelo]
# 1693  [NikolaMilenkovic, GermanPezzella, DavideAstor...
# 1694  [BartoszBereszynski, MatiasSilvestre, GianMarc...
# 1695     [AntonioCaracciolo, DeianBoldor, JagosVukovic]
# 1696    [LucaRossettini, NicolasSpolli, ErvinZukanovic]
# 1697  [BacarySagna, BeratDjimsiti, AlinTosca, Gaetan...
# 1698      [ThiagoCionek, FrancescoVicari, LorencoSimic]
# 1699  [JensStrygerLarsen, DaniloLarangeira, SamirSan...
# 1700                  [Wallace, LuizFelipe, StefanRadu]
# 1701  [FabrizioCacciatore, MattiaBani, AlessandroGam...
# 1702  [LorenzoDeSilvestri, NicolasNkoulou, NicolasBu...
# 1703  [DavideCalabria, LeonardoBonucci, AlessioRomag...
# 1704  [ElseidHysaj, RaulAlbiol, KalidouKoulibaly, Ma...
# 1705  [SebastienDeMaio, GiancarloGonzalez, FilipHela...
# 1706      [AndreaBarzagli, MedhiBenatia, DanieleRugani]
# 1707  [AlessandroFlorenzi, KostasManolas, FedericoFa...
# 1708  [LorenzoDeSilvestri, NicolasNkoulou, EmilianoM...
# 1709  [FabrizioCacciatore, DarioDainelli, MattiaBani...
# 1710  [BacarySagna, BeratDjimsiti, AlinTosca, Lorenz...
# 1711             [LuizFelipe, StefandeVrij, StefanRadu]
# 1712    [RafaelToloi, JoseLuisPalomino, AndreaMasiello]
# 1713     [ThiagoCionek, FrancescoVicari, FelipedalBelo]
# 1714  [SilvanWidmer, BramNuytinck, GabrieleAngella, ...
# 1715  [JacopoSala, MatiasSilvestre, GianMarcoFerrari...
# 1716  [FabioBorini, LeonardoBonucci, AlessioRomagnol...
# 1717  [ElseidHysaj, RaulAlbiol, KalidouKoulibaly, Ma...
# 1718   [RafaelToloi, GianlucaMancini, JoseLuisPalomino]
# 1719  [EdoardoGoldaniga, FrancescoAcerbi, CristianDe...
# 1720  [MattiaDeSciglio, DanieleRugani, GiorgioChiell...
# 1721  [JoaoCancelo, MilanSkriniar, Miranda, DaniloDA...
# 1722    [FilippoRomagna, LucaCeppitelli, LeandroCastan]
# 1723  [FabrizioCacciatore, NenadTomovic, MattiaBani,...
# 1724  [NikolaMilenkovic, GermanPezzella, VitorHugo, ...
# 1725  [BrunoPeres, FedericoFazio, JuanJesus, Aleksan...
# 1726    [RafaelToloi, JoseLuisPalomino, AndreaMasiello]
# 1727  [SebastienDeMaio, GiancarloGonzalez, FilipHela...
# 1728    [DavideBiraschi, NicolasSpolli, ErvinZukanovic]
# 1729  [AlessandroFlorenzi, KostasManolas, FedericoFa...
# 1730  [JensStrygerLarsen, DaniloLarangeira, BramNuyt...
# 1731  [AlexFerrari, AntonioCaracciolo, JagosVukovic,...
# 1732            [BeratDjimsiti, AndreaCosta, AlinTosca]
# 1733  [DavideFaraoni, FedericoCeccherini, MarcoCapua...
# 1734  [NicolasNkoulou, NicolasBurdisso, EmilianoMore...
# 1735     [ThiagoCionek, FrancescoVicari, FelipedalBelo]
# 1736  [ElseidHysaj, RaulAlbiol, KalidouKoulibaly, Ma...
# 1737  [JacopoSala, MatiasSilvestre, VascoRegini, Nic...
# 1738  [DavideCalabria, LeonardoBonucci, AlessioRomag...
# 1739    [MarcoAndreolli, LucaCeppitelli, FabioPisacane]
# 1740  [BartoszBereszynski, JoachimAndersen, GianMarc...
# 1741      [NikolaMilenkovic, GermanPezzella, VitorHugo]
# 1742  [AlexFerrari, AntonioCaracciolo, JagosVukovic,...
# 1743  [FedericoCeccherini, ArlindAjeti, MarioSampirisi]
# 1744  [JoaoCancelo, MilanSkriniar, Miranda, DaniloDA...
# 1745  [EdoardoGoldaniga, FrancescoAcerbi, CristianDe...
# 1746  [StephanLichtsteiner, MedhiBenatia, DanieleRug...
# 1747  [VincentLaurini, GermanPezzella, VitorHugo, Cr...
# 1748  [AndreaMasiello, GianlucaMancini, JoseLuisPalo...
# 1749    [DavideBiraschi, NicolasSpolli, ErvinZukanovic]
# 1750  [JoaoCancelo, MilanSkriniar, Miranda, DaniloDA...
# 1751  [FabioDepaoli, NenadTomovic, MattiaBani, Massi...
# 1752     [FabioPisacane, FilippoRomagna, LeandroCastan]
# 1753  [VasilisTorosidis, SebastienDeMaio, FilipHelan...
# 1754                 [Bastos, StefandeVrij, LuizFelipe]
# 1755   [MauricioLemos, FrancescoAcerbi, FedericoPeluso]
# 1756      [BramNuytinck, DaniloLarangeira, SamirSantos]
# 1757  [NicolasNkoulou, NicolasBurdisso, EmilianoMore...
# 1758  [DavideFaraoni, FedericoCeccherini, MarioSampi...
# 1759          [MilanSkriniar, Miranda, DaniloDAmbrosio]
# 1760     [ThiagoCionek, FrancescoVicari, FelipedalBelo]
# 1761  [AlexFerrari, AntonioCaracciolo, JagosVukovic,...
# 1762  [BacarySagna, BeratDjimsiti, AlinTosca, Gaetan...
# 1763  [ChristianMaggio, RaulAlbiol, KalidouKoulibaly...
# 1764  [JacopoSala, MatiasSilvestre, GianMarcoFerrari...
# 1765          [FedericoFazio, KostasManolas, JuanJesus]
# 1766    [FilippoRomagna, MarcoAndreolli, LeandroCastan]
# 1767   [GianlucaMancini, MattiaCaldara, AndreaMasiello]
# 1768     [JawadElYamiq, LucaRossettini, ErvinZukanovic]
# 1769  [AlessandroGamberini, IvanRadovanovic, NenadTo...
# 1770  [GiancarloGonzalez, SimoneRomagnoli, FilipHela...
# 1771  [StephanLichtsteiner, DanieleRugani, MedhiBena...
# 1772          [MartinCaceres, StefandeVrij, LuizFelipe]
# 1773  [IgnazioAbate, LeonardoBonucci, CristianZapata...
# 1774   [MauricioLemos, FrancescoAcerbi, FedericoPeluso]
# 1775      [BramNuytinck, DaniloLarangeira, SamirSantos]
# 1776  [BrunoPeres, KostasManolas, FedericoFazio, Jon...
# 1777  [VincentLaurini, NikolaMilenkovic, VitorHugo, ...
# 1778  [BacarySagna, BeratDjimsiti, AlinTosca, Gaetan...
# 1779  [GiancarloGonzalez, SimoneRomagnoli, Sebastien...
# 1780  [NicolasNkoulou, NicolasBurdisso, EmilianoMore...
# 1781  [DavideFaraoni, FedericoCeccherini, MarcoCapua...
# 1782  [JoaoCancelo, MilanSkriniar, Miranda, DaniloDA...
# 1783  [BartoszBereszynski, JoachimAndersen, GianMarc...
# 1784  [ElseidHysaj, RaulAlbiol, KalidouKoulibaly, Ma...
# 1785  [EnricoBearzotti, AntonioCaracciolo, JagosVuko...
# 1786        [MattiaBani, IvanRadovanovic, NenadTomovic]
# 1787  [JuanCuadrado, DanieleRugani, AndreaBarzagli, ...
# 1788   [MauricioLemos, FrancescoAcerbi, FedericoPeluso]
# 1789  [DavideCalabria, CristianZapata, LeonardoBonuc...
# 1790   [DavideBiraschi, LucaRossettini, ErvinZukanovic]
# 1791  [JensStrygerLarsen, DaniloLarangeira, SamirSan...
# 1792     [ThiagoCionek, FrancescoVicari, FelipedalBelo]
# 1793     [FabioPisacane, LucaCeppitelli, LeandroCastan]
# 1794  [ElseidHysaj, RaulAlbiol, KalidouKoulibaly, Ma...
# 1795             [LuizFelipe, StefandeVrij, StefanRadu]
# 1796  [EnricoBearzotti, AntonioCaracciolo, ThomasHeu...
# 1797  [IbrahimaMbaye, SimoneRomagnoli, SebastienDeMaio]
# 1798  [JoaoCancelo, AndreaRanocchia, MilanSkriniar, ...
# 1799   [NicolasNkoulou, NicolasBurdisso, KevinBonifazi]
# 1800  [BrunoGaspar, GermanPezzella, NikolaMilenkovic...
# 1801        [LorenzoVenuti, BeratDjimsiti, BacarySagna]
# 1802    [RafaelToloi, JoseLuisPalomino, AndreaMasiello]
# 1803  [DavideFaraoni, FedericoCeccherini, MarcoCapua...
# 1804  [BartoszBereszynski, MatiasSilvestre, JoachimA...
# 1805  [BrunoPeres, ElioCapradossi, FedericoFazio, Al...
# 1806        [DavideBiraschi, JawadElYamiq, ArmandoIzzo]
# 1807  [MauricioLemos, FrancescoAcerbi, CristianDellO...
# 1808  [FabioDepaoli, DarioDainelli, NenadTomovic, Ma...
# 1809                [Wallace, StefandeVrij, StefanRadu]
# 1810      [BramNuytinck, DaniloLarangeira, SamirSantos]
# 1811  [PaoloFarago, FabioPisacane, LucaCeppitelli, C...
# 1812      [ThiagoCionek, BartoszSalamon, FelipedalBelo]
# 1813  [IgnazioAbate, LeonardoBonucci, AlessioRomagno...
# 1814  [MattiaDeSciglio, DanieleRugani, AndreaBarzagl...
# 1815  [ElseidHysaj, RaulAlbiol, KalidouKoulibaly, Ma...
# 1816  [AlexFerrari, AntonioCaracciolo, SamuelSoupray...
# 1817   [KevinBonifazi, NicolasNkoulou, EmilianoMoretti]
# 1818  [DavideFaraoni, FedericoCeccherini, MarcoCapua...
# 1819  [BacarySagna, BeratDjimsiti, AlinTosca, Gaetan...
# 1820  [VasilisTorosidis, SimoneRomagnoli, SebastienD...
# 1821  [NikolaMilenkovic, GermanPezzella, VitorHugo, ...
# 1822  [BartoszBereszynski, JoachimAndersen, VascoReg...
# 1823  [TimothyCastagne, MattiaCaldara, JoseLuisPalom...
# 1824  [JoaoCancelo, MilanSkriniar, Miranda, DaniloDA...
# 1825  [AlessandroFlorenzi, KostasManolas, FedericoFa...

# %%
defence['home_team'].unique()
# Out:
# array(['Arsenal', 'Watford', 'West Brom', 'Everton', 'Southampton',
#        'Chelsea', 'Crystal Palace', 'Brighton', 'Newcastle Utd',
#        'Manchester Utd', 'Swansea City', 'Leicester City', 'Bournemouth',
#        'Burnley', 'Liverpool', 'Stoke City', 'Huddersfield', 'Tottenham',
#        'Manchester City', 'West Ham', 'Bayern Munich', 'Hoffenheim',
#        'Mainz 05', 'Wolfsburg', 'Hamburger SV', 'Hertha BSC',
#        'Schalke 04', 'Freiburg', "M'Gladbach", 'Köln', 'Stuttgart',
#        'Eint Frankfurt', 'Werder Bremen', 'Leverkusen', 'Augsburg',
#        'Dortmund', 'RB Leipzig', 'Hannover 96', 'Monaco', 'Paris S-G',
#        'Saint-Étienne', 'Montpellier', 'Metz', 'Lyon', 'Troyes', 'Lille',
#        'Angers', 'Marseille', 'Nice', 'Rennes', 'Nantes', 'Amiens',
#        'Toulouse', 'Caen', 'Bordeaux', 'Strasbourg', 'Dijon', 'Guingamp',
#        'Leganés', 'Valencia', 'Celta Vigo', 'Girona', 'Sevilla',
#        'Athletic Club', 'Barcelona', 'La Coruña', 'Levante', 'Málaga',
#        'Real Sociedad', 'Betis', 'Alavés', 'Las Palmas', 'Espanyol',
#        'Eibar', 'Getafe', 'Real Madrid', 'Villarreal', 'Atlético Madrid',
#        'Juventus', 'Hellas Verona', 'Atalanta', 'Sampdoria', 'Crotone',
#        'Bologna', 'Udinese', 'Lazio', 'Inter', 'Sassuolo', 'Benevento',
#        'Genoa', 'Roma', 'Torino', 'Chievo', 'SPAL', 'Napoli',
#        'Fiorentina', 'Milan', 'Cagliari'], dtype=object)

# %%
#defence.drop(columns = ['Unnamed: 0'], inplace=True)

# %%
# def clean_tokenize(s):
#     s = s.replace(",", ' ')
#     s = s.replace("[", '')
#     s = s.replace("]", '')
#     s = s.replace("'", '')
#     s = s.split()
#     return s

# %%
# defence['home_team_defs'] = defence['home_team_defs'].apply(lambda x: clean_tokenize(x))
# defence['away_team_defs'] = defence['away_team_defs'].apply(lambda x: clean_tokenize(x))

# %%
def add_home_posn(df):
    for i in range(0, len(df)):
        if(len(df['home_team_defs'][i])==4):
            df['home_RB'][i] = df['home_team_defs'][i][0]
            df['home_R-CB'][i] = df['home_team_defs'][i][1]
            df['home_L-CB'][i] = df['home_team_defs'][i][2]
            df['home_LB'][i] = df['home_team_defs'][i][3]
            df['home_backline'][i] = 4
        elif(len(df['home_team_defs'][i])==3):
            df['home_RCB'][i] = df['home_team_defs'][i][0]
            df['home_CB'][i] = df['home_team_defs'][i][1]
            df['home_LCB'][i] = df['home_team_defs'][i][2]
            df['home_backline'][i] = 3
        else:
            df['home_RWB'][i] = df['home_team_defs'][i][0]
            df['home_RCB'][i] = df['home_team_defs'][i][1]
            df['home_CB'][i] = df['home_team_defs'][i][2]
            df['home_LCB'][i] = df['home_team_defs'][i][3]
            df['home_LWB'][i] = df['home_team_defs'][i][4]
            df['home_backline'][i] = 5

# %%
def add_away_posn(df):
    for i in range(0, len(df)):
        if(len(df['away_team_defs'][i])==4):
            df['away_RB'][i] = df['away_team_defs'][i][0]
            df['away_R-CB'][i] = df['away_team_defs'][i][1]
            df['away_L-CB'][i] = df['away_team_defs'][i][2]
            df['away_LB'][i] = df['away_team_defs'][i][3]
            df['away_backline'][i] = 4
        elif(len(df['away_team_defs'][i])==3):
            df['away_RCB'][i] = df['away_team_defs'][i][0]
            df['away_CB'][i] = df['away_team_defs'][i][1]
            df['away_LCB'][i] = df['away_team_defs'][i][2]
            df['away_backline'][i] = 3
        else:
            df['away_RWB'][i] = df['away_team_defs'][i][0]
            df['away_RCB'][i] = df['away_team_defs'][i][1]
            df['away_CB'][i] = df['away_team_defs'][i][2]
            df['away_LCB'][i] = df['away_team_defs'][i][3]
            df['away_LWB'][i] = df['away_team_defs'][i][4]
            df['away_backline'][i] = 5

# %%
defence = defence.reindex(columns=defence.columns.tolist() + [
    'home_RB',
    'home_R-CB',
    'home_L-CB',
    'home_LB',
    'home_RCB',
    'home_CB',
    'home_LCB',
    'home_RWB',
    'home_LWB',
    'away_RB',
    'away_R-CB',
    'away_L-CB',
    'away_LB',
    'away_RCB',
    'away_CB',
    'away_LCB',
    'away_RWB',
    'away_LWB',
    'home_backline',
    'away_backline'
# 1797            364  1 - 1         Tottenham Hotspur                   Burnley
# 1798            364  2 - 0                   Chelsea                   Everton
# 1799            364  1 - 1      West Bromwich Albion                Stoke City
# 1800            364  2 - 0         Manchester United            Leicester City
# 1801            364  0 - 2            Crystal Palace              Swansea City
# 1802            364  0 - 0         Huddersfield Town               Southampton
# 1803            364  3 - 0          Newcastle United           West Ham United
# 1804            364  0 - 0                   Watford    Brighton & Hove Albion
# 1805            364  1 - 2           AFC Bournemouth           Manchester City
# 1806            364  1 - 1           Manchester City                   Everton
# 1807            364  1 - 2         Tottenham Hotspur                   Chelsea
# 1808            364  1 - 0         Huddersfield Town          Newcastle United
# 1809            364  1 - 0                Stoke City                   Arsenal
# 1810            364  0 - 2           AFC Bournemouth                   Watford
# 1811            364  0 - 1                   Burnley      West Bromwich Albion
# 1812            364  2 - 0            Leicester City    Brighton & Hove Albion
# 1813            364  1 - 0                 Liverpool            Crystal Palace
# 1814            364  3 - 2               Southampton           West Ham United
# 1815            364  0 - 4              Swansea City         Manchester United
# 1816            364  4 - 0         Manchester United           West Ham United
# 1817            364  0 - 2          Newcastle United         Tottenham Hotspur
# 1818            364  0 - 2    Brighton & Hove Albion           Manchester City
# 1819            364  2 - 3                   Chelsea                   Burnley
# 1820            364  0 - 3            Crystal Palace         Huddersfield Town
# 1821            364  1 - 0                   Everton                Stoke City
# 1822            364  0 - 0               Southampton              Swansea City
# 1823            364  1 - 0      West Bromwich Albion           AFC Bournemouth
# 1824            364  3 - 3                   Watford                 Liverpool
# 1825            364  4 - 3                   Arsenal            Leicester City

# %%
defence.tournament.unique()
# Out:
# array(['Premier League', 'Bundesliga', 'Ligue 1 Conforama',
#        'LaLiga Santander', 'Serie A TIM'], dtype=object)

# %%
matches1['home_team'] = matches1['home_team'].swifter.set_npartitions(
    8).apply(lambda x: x.encode().decode('unicode_escape').replace('\xad',''))
matches1['away_team'] = matches1['away_team'].swifter.set_npartitions(
    8).apply(lambda x: x.encode().decode('unicode_escape').replace('\xad',''))
# Out:
# HBox(children=(HTML(value='Pandas Apply'), FloatProgress(value=0.0, max=1826.0), HTML(value='')))
# HBox(children=(HTML(value='Pandas Apply'), FloatProgress(value=0.0, max=1826.0), HTML(value='')))

# %%
sorted(matches1[matches1['competitionId']==524].home_team.unique())
# Out:
# ['Atalanta',
#  'Benevento',
#  'Bologna',
#  'Cagliari',
#  'Chievo',
#  'Crotone',
#  'Fiorentina',
#  'Genoa',
#  'Hellas Verona',
#  'Internazionale',
#  'Juventus',
#  'Lazio',
#  'Milan',
#  'Napoli',
#  'Roma',
#  'SPAL',
#  'Sampdoria',
#  'Sassuolo',
#  'Torino',
#  'Udinese']

# %%
sorted(defence[defence['tournament']=='Bundesliga'].home_team.unique())
# Out:
# ['Augsburg',
#  'Bayern Munich',
#  'Dortmund',
#  'Eint Frankfurt',
#  'Freiburg',
#  'Hamburger SV',
#  'Hannover 96',
#  'Hertha BSC',
#  'Hoffenheim',
#  'Köln',
#  'Leverkusen',
#  "M'Gladbach",
#  'Mainz 05',
#  'RB Leipzig',
#  'Schalke 04',
#  'Stuttgart',
#  'Werder Bremen',
#  'Wolfsburg']

# %%
matches1 = matches1.replace({
    'home_team': {
        'Brighton & Hove Albion': 'Brighton',
        'AFC Bournemouth': 'Bournemouth',
        'Huddersfield Town': 'Huddersfield',
        'Manchester United': 'Manchester Utd',
        'Newcastle United': 'Newcastle Utd',
        'Tottenham Hotspur': 'Tottenham',
        'West Bromwich Albion': 'West Brom',
        'West Ham United': 'West Ham',
        'Bayer Leverkusen': 'Leverkusen',
        'Bayern München': 'Bayern Munich',
        'Borussia Dortmund': 'Dortmund',
        "Borussia M'gladbach": "M'Gladbach",
        'Eintracht Frankfurt': 'Eint Frankfurt',
        'Amiens SC': 'Amiens',
        'Angers SCO': 'Angers',
        'Olympique Lyonnais': 'Lyon',
        'PSG': 'Paris S-G',
        'Olympique Marseille': 'Marseille',
        'Deportivo Alavés': 'Alavés',
        'Real Betis': 'Betis',
        'Celta de Vigo': 'Celta Vigo',
        'Deportivo La Coruña': 'La Coruña',
        'Internazionale': 'Inter'
    },
    'away_team': {
        'Brighton & Hove Albion': 'Brighton',
        'AFC Bournemouth': 'Bournemouth',
        'Huddersfield Town': 'Huddersfield',
        'Manchester United': 'Manchester Utd',
        'Newcastle United': 'Newcastle Utd',
        'Tottenham Hotspur': 'Tottenham',
        'West Bromwich Albion': 'West Brom',
        'West Ham United': 'West Ham',
        'Bayer Leverkusen': 'Leverkusen',
        'Bayern München': 'Bayern Munich',
        'Borussia Dortmund': 'Dortmund',
        "Borussia M'gladbach": "M'Gladbach",
        'Eintracht Frankfurt': 'Eint Frankfurt',
        'Amiens SC': 'Amiens',
        'Angers SCO': 'Angers',
        'Olympique Lyonnais': 'Lyon',
        'PSG': 'Paris S-G',
        'Olympique Marseille': 'Marseille',
        'Deportivo Alavés': 'Alavés',
        'Real Betis': 'Betis',
        'Celta de Vigo': 'Celta Vigo',
        'Deportivo La Coruña': 'La Coruña',
        'Internazionale': 'Inter'
    }
})

# %%
matches1.drop(columns=['label'], inplace=True)
matches1['match'] = matches1['home_team'] + '-' + matches1['away_team']

# %%
defence['match'] = defence['home_team'] + '-' + defence['away_team']

# %%
match_def = pd.merge(right=matches1, left=defence, right_on='match', left_on='match')

# %%
match_def.shape
# Out:
# (1826, 46)

# %%
match_def.columns
# Out:
# Index(['tournament', 'gameweek_x', 'date_x', 'home_team_x', 'score_x',
#        'away_team_x', 'match_link', 'home_team_defs', 'away_team_defs',
#        'home_RB', 'home_R-CB', 'home_L-CB', 'home_LB', 'home_RCB', 'home_CB',
#        'home_LCB', 'home_RWB', 'home_LWB', 'away_RB', 'away_R-CB', 'away_L-CB',
#        'away_LB', 'away_RCB', 'away_CB', 'away_LCB', 'away_RWB', 'away_LWB',
#        'home_backline', 'away_backline', 'match', 'status', 'roundId',
#        'gameweek_y', 'teamsData', 'seasonId', 'dateutc', 'winner', 'venue',
#        'wyId', 'date_y', 'referees', 'duration', 'competitionId', 'score_y',
#        'home_team_y', 'away_team_y'],
#       dtype='object')

# %%
match_def.drop(columns=[
    'status', 'roundId', 'seasonId', 'date_x', 'winner',
    'duration', 'competitionId', 'home_team_y', 'away_team_y', 'match_link'
], inplace=True)

# %%
len(match_def)
# Out:
# 1826

# %%
match_def.to_pickle('../data_top5/matches/matches_defence_top5.pkl')

# %% [markdown]
# # Event Data Pre-Processing

# %% [markdown]
# ## Normalizing Names

# %%
events_com = pd.read_pickle('../data_top5/events/events_com.pkl')

# %%
events_com['firstName'] = events_com['firstName'].swifter.set_npartitions(
    8).apply(lambda x: x.encode().decode('unicode_escape').replace('\xad',''))
events_com['lastName'] = events_com['lastName'].swifter.set_npartitions(
    8).apply(lambda x: x.encode().decode('unicode_escape').replace('\xad',''))
# Out:
# HBox(children=(HTML(value='Pandas Apply'), FloatProgress(value=0.0, max=2845357.0), HTML(value='')))
# HBox(children=(HTML(value='Pandas Apply'), FloatProgress(value=0.0, max=2845357.0), HTML(value='')))

# %%
players['firstName'] = players['firstName'].swifter.set_npartitions(
    8).apply(lambda x: x.encode().decode('unicode_escape').replace('\xad',''))
players['lastName'] = players['lastName'].swifter.set_npartitions(
    8).apply(lambda x: x.encode().decode('unicode_escape').replace('\xad',''))
players['playerName'] = players['firstName']+players['lastName']
players['playerName'] = players['playerName'].apply(lambda x: unidecode(x))
# Out:
# HBox(children=(HTML(value='Pandas Apply'), FloatProgress(value=0.0, max=3603.0), HTML(value='')))
# HBox(children=(HTML(value='Pandas Apply'), FloatProgress(value=0.0, max=3603.0), HTML(value='')))

# %%
players['playerName'] = players['playerName'].apply(lambda x: x.replace('-', ''))

# %%
players['playerName'] = players['playerName'].apply(lambda x: x.replace(' ', ''))

# %%
players.at[players[players['playerName']=='DiegoGonzalezPolanco']['foot'].index[0], 'foot'] = 'left'
players.at[players[players['playerName']=='MujaidSadickAliu']['foot'].index[0], 'foot'] = 'right'
players.at[players[players['playerName']=='DavidAlbaFernandez']['foot'].index[0], 'foot'] = 'right'
players.at[players[players['playerName']=='DavidAlcibiade']['foot'].index[0], 'foot'] = 'right'
players.at[players[players['playerName']=='DylanLempereur']['foot'].index[0], 'foot'] = 'left'

# %%
players.to_pickle('../data_top5/players/players.pkl')

# %% [markdown]
# ## Modifying match_def

# %%
match_def.columns
# Out:
# Index(['tournament', 'gameweek_x', 'home_team_x', 'score_x', 'away_team_x',
#        'home_team_defs', 'away_team_defs', 'home_RB', 'home_R-CB', 'home_L-CB',
#        'home_LB', 'home_RCB', 'home_CB', 'home_LCB', 'home_RWB', 'home_LWB',
#        'away_RB', 'away_R-CB', 'away_L-CB', 'away_LB', 'away_RCB', 'away_CB',
#        'away_LCB', 'away_RWB', 'away_LWB', 'home_backline', 'away_backline',
#        'match', 'gameweek_y', 'teamsData', 'dateutc', 'venue', 'wyId',
#        'date_y', 'referees', 'score_y'],
#       dtype='object')

# %%
match_def.columns
# Out:
# Index(['tournament', 'gameweek_x', 'home_team_x', 'score_x', 'away_team_x',
#        'home_team_defs', 'away_team_defs', 'home_RB', 'home_R-CB', 'home_L-CB',
#        'home_LB', 'home_RCB', 'home_CB', 'home_LCB', 'home_RWB', 'home_LWB',
#        'away_RB', 'away_R-CB', 'away_L-CB', 'away_LB', 'away_RCB', 'away_CB',
#        'away_LCB', 'away_RWB', 'away_LWB', 'home_backline', 'away_backline',
#        'match', 'gameweek_y', 'teamsData', 'dateutc', 'venue', 'wyId',
#        'date_y', 'referees', 'score_y'],
#       dtype='object')

# %%
match_def_away = match_def[['wyId', 'away_team_x', 'away_team_defs', 'away_RB', 'away_R-CB', 'away_L-CB', 'away_LB', 'away_RCB',
       'away_CB', 'away_LCB', 'away_RWB', 'away_LWB', 'away_backline', 'match', 'gameweek_x', 'teamsData',
       'dateutc', 'venue', 'referees', 'score_x']]

# %%
match_def_away.columns = ['wyId', 'team', 'team_defense', 'RB', 'R-CB', 'L-CB', 'LB', 'RCB',
       'CB', 'LCB', 'RWB', 'LWB', 'backline', 'match', 'gameweek', 'teamsData',
       'dateutc', 'venue', 'referees', 'score']

# %%
match_def = match_def[['wyId', 'home_team_x', 'home_team_defs', 'home_RB', 'home_R-CB', 'home_L-CB', 'home_LB', 'home_RCB',
       'home_CB', 'home_LCB', 'home_RWB', 'home_LWB', 'home_backline', 'match', 'gameweek_x', 'teamsData',
       'dateutc', 'venue', 'referees', 'score_x']]

# %%
match_def.columns = ['wyId', 'team', 'team_defense', 'RB', 'R-CB', 'L-CB', 'LB', 'RCB',
       'CB', 'LCB', 'RWB', 'LWB', 'backline', 'match', 'gameweek', 'teamsData',
       'dateutc', 'venue', 'referees', 'score']

# %%
match_def = match_def.append(match_def_away, ignore_index=True)

# %%
match_def.sort_values(by=['gameweek'], inplace=True, ascending=False)

# %%
match_def.reset_index(drop=True, inplace=True)

# %%
match_def.to_pickle('../data_top5/matches/match+def_lineup_top5.pkl')

# %% [markdown]
# ## Adding Footedness

# %%
events_com['playerName'] = events_com['firstName']+events_com['lastName']
events_com['playerName'] = events_com['playerName'].apply(lambda x: unidecode(x))
events_com['playerName'] = events_com['playerName'].apply(lambda x: x.replace(" ", ''))
events_com['playerName'] = events_com['playerName'].apply(lambda x: x.replace('-', ''))
events_com.drop(columns=[
    'currentTeamId', 'passportArea', 'weight', 'firstName', 'lastName',
    'middleName', 'birthDate', 'height', 'role', 'birthArea', 'shortName',
    'currentNationalTeamId'
], inplace=True)
# events_com.rename(columns={'id': 'eventId', 'wyId': 'playerId'})

# %%
events_com.to_pickle('../data_top5/events/events_com.pkl')

# %%
events_com = pd.read_pickle('../data_top5/events/events_com.pkl')
match_def = pd.read_pickle('../data_top5/matches/match+def_lineup_top5.pkl')

# %%
imp = pd.DataFrame(match_def[['team', 'team_defense', 'wyId']].explode('team_defense'))

# %%
imp.loc[((imp['team'] == 'Real Madrid') & (imp['team_defense'] == 'Marcelo')),
        'team_defense'] = 'MarceloVieiradaSilvaJunior'
imp.loc[((imp['team'] == 'Lyon') & (imp['team_defense'] == 'Marcelo')),
        'team_defense'] = 'MarceloAntonioGuedesFilho'
imp.loc[((imp['team'] == 'Atlético Madrid') &
         (imp['team_defense'] == 'Juanfran')),
        'team_defense'] = 'JuanFranciscoTorresBelen'
imp.loc[((imp['team'] == 'La Coruña') &
         (imp['team_defense'] == 'Juanfran')),
        'team_defense'] = 'JuanFranciscoMorenoFuertes'
imp.loc[((imp['team'] == 'Schalke 04') &
         (imp['team_defense'] == 'Naldo')),
        'team_defense'] = 'RonaldoAparecidoRodrigues'
imp.loc[((imp['team'] == 'Espanyol') &
         (imp['team_defense'] == 'Naldo')),
        'team_defense'] = 'EdinaldoGomesPereira'

# %%
imp = pd.DataFrame(imp.groupby(['wyId', 'team'])['team_defense'].apply(list)).reset_index()

# %%
match_def = match_def.sort_values(by=['wyId', 'team']).reset_index(drop=True)
match_def['team_defense'] = imp['team_defense']
match_def.to_pickle('../data_top5/matches/match+def_lineup_top5.pkl')

# %%
match_def = pd.read_pickle('../data_top5/matches/match+def_lineup_top5.pkl')

# %%
a = pd.DataFrame(match_def[['team_defense', 'backline']].explode('team_defense'))

# %%
players = pd.read_pickle('../data_top5/players/players.pkl')

# %%
p = players[['playerName', 'foot']]

# %%
b = pd.merge(right=p, left=a, right_on='playerName', left_on='team_defense', how='left')

# %% [markdown]
# Storing the mismatch names in np array

# %%
np.save('../data_top5/players/mismatch_names.npy', b[b['foot'].isna()]['team_defense'].unique())

# %% [markdown]
# **Importing PlayerMap to match names across DFs**

# %%
player_map = pd.read_csv('../data_top5/players/PlayerMap.csv')

# %%
player_map.head()
# Out:
#         Lineup Name                   Wyscout Name
# 0     FelipedalBelo       FelipeDiasdaSilvadalBelo
# 1    CristianZapata  CristianEduardoZapataValencia
# 2  RicardoRodriguez      RicardoIvanRodriguezAraya
# 3    AliAdnanKadhim        AliAdnanKadhimAlTameemi
# 4       SamirSantos      SamirCaetanodeSouzaSantos

# %%
player_map.drop([
    player_map[player_map['Lineup Name'] == 'Naldo'].index[0],
    player_map[player_map['Lineup Name'] == 'Marcelo'].index[0],
    player_map[player_map['Lineup Name']=='Juanfran'].index[0]
], inplace=True)
player_map.reset_index(drop=True, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-75-7175aa37115a> in <module>
#       1 player_map.drop([
# ----> 2     player_map[player_map['Lineup Name'] == 'Naldo'].index[0],
#       3     player_map[player_map['Lineup Name'] == 'Marcelo'].index[0],
#       4     player_map[player_map['Lineup Name']=='Juanfran'].index[0]
#       5 ], inplace=True)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in __getitem__(self, key)
#    4099         if is_scalar(key):
#    4100             key = com.cast_scalar_indexer(key, warn_float=True)
# -> 4101             return getitem(key)
#    4102
#    4103         if isinstance(key, slice):
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
player_map.to_csv('../data_top5/players/PlayerMap.csv')

# %%
player_map = dict([(i,a) for i, a in zip(player_map['Lineup Name'], player_map['Wyscout Name'])])

# %%
a = match_def[['team_defense', 'backline']].explode('team_defense')
a = a.replace({'team_defense': player_map})
p = players[['playerName', 'foot']]
b = pd.merge(right=p, left=a, right_on='playerName', left_on='team_defense', how='left')

# %%
b['foot'].isna().sum()
# Out:
# 0

# %%
b[b['foot'].isna()]['team_defense'].unique()
# Out:
# array([], dtype=object)

# %%
b.index = a.index

# %%
f = [list(b['foot'][i]) for i in a.index.unique()]
f = pd.Series(f)
match_def['footedness'] = f.values
match_def['footedness'] = match_def['footedness'].apply(lambda x: '-'.join(x))

# %%
match_def.reset_index(drop=True, inplace=True)
# match_def.rename(columns={'wyId': 'matchId'})

# %%
match_def
# Out:
#          wyId             team  \
# 0     2499719          Arsenal
# 1     2499719   Leicester City
# 2     2499720         Brighton
# 3     2499720  Manchester City
# 4     2499721          Burnley
# ...       ...              ...
# 3647  2576336         Sassuolo
# 3648  2576337             SPAL
# 3649  2576337        Sampdoria
# 3650  2576338            Genoa
# 3651  2576338           Torino
#
#                                            team_defense                  RB  \
# 0             [RobHolding, NachoMonreal, SeadKolasinac]                 NaN
# 1     [DannySimpson, WesMorgan, HarryMaguire, Christ...        DannySimpson
# 2         [Bruno, LewisDunk, ShaneDuffy, MarkusSuttner]               Bruno
# 3         [VincentKompany, JohnStones, NicolasOtamendi]                 NaN
# 4     [MatthewLowton, JamesTarkowski, BenMee, Stephe...       MatthewLowton
# ...                                                 ...                 ...
# 3647   [MauricioLemos, FrancescoAcerbi, FedericoPeluso]                 NaN
# 3648     [LorencoSimic, FrancescoVicari, FelipedalBelo]                 NaN
# 3649  [BartoszBereszynski, JoachimAndersen, VascoReg...  BartoszBereszynski
# 3650        [DavideBiraschi, JawadElYamiq, ArmandoIzzo]                 NaN
# 3651   [KevinBonifazi, NicolasNkoulou, EmilianoMoretti]                 NaN
#
#                  R-CB          L-CB              LB             RCB  \
# 0                 NaN           NaN             NaN      RobHolding
# 1           WesMorgan  HarryMaguire  ChristianFuchs             NaN
# 2           LewisDunk    ShaneDuffy   MarkusSuttner             NaN
# 3                 NaN           NaN             NaN  VincentKompany
# 4      JamesTarkowski        BenMee     StephenWard             NaN
# ...               ...           ...             ...             ...
# 3647              NaN           NaN             NaN   MauricioLemos
# 3648              NaN           NaN             NaN    LorencoSimic
# 3649  JoachimAndersen   VascoRegini     NicolaMurru             NaN
# 3650              NaN           NaN             NaN  DavideBiraschi
# 3651              NaN           NaN             NaN   KevinBonifazi
#
#                    CB              LCB  RWB  LWB  backline  \
# 0        NachoMonreal    SeadKolasinac  NaN  NaN       3.0
# 1                 NaN              NaN  NaN  NaN       4.0
# 2                 NaN              NaN  NaN  NaN       4.0
# 3          JohnStones  NicolasOtamendi  NaN  NaN       3.0
# 4                 NaN              NaN  NaN  NaN       4.0
# ...               ...              ...  ...  ...       ...
# 3647  FrancescoAcerbi   FedericoPeluso  NaN  NaN       3.0
# 3648  FrancescoVicari    FelipedalBelo  NaN  NaN       3.0
# 3649              NaN              NaN  NaN  NaN       4.0
# 3650     JawadElYamiq      ArmandoIzzo  NaN  NaN       3.0
# 3651   NicolasNkoulou  EmilianoMoretti  NaN  NaN       3.0
#
#                          match gameweek  \
# 0       Arsenal-Leicester City        1
# 1       Arsenal-Leicester City        1
# 2     Brighton-Manchester City        1
# 3     Brighton-Manchester City        1
# 4              Chelsea-Burnley        1
# ...                        ...      ...
# 3647             Sassuolo-Roma       38
# 3648            SPAL-Sampdoria       38
# 3649            SPAL-Sampdoria       38
# 3650              Genoa-Torino       38
# 3651              Genoa-Torino       38
#
#                                               teamsData              dateutc  \
# 0     {'1609': {'scoreET': 0, 'coachId': 7845, 'side...  2017-08-11 18:45:00
# 1     {'1609': {'scoreET': 0, 'coachId': 7845, 'side...  2017-08-11 18:45:00
# 2     {'1651': {'scoreET': 0, 'coachId': 8093, 'side...  2017-08-12 16:30:00
# 3     {'1651': {'scoreET': 0, 'coachId': 8093, 'side...  2017-08-12 16:30:00
# 4     {'1646': {'scoreET': 0, 'coachId': 8880, 'side...  2017-08-12 14:00:00
# ...                                                 ...                  ...
# 3647  {'3158': {'scoreET': 0, 'coachId': 210119, 'si...  2018-05-20 18:45:00
# 3648  {'3164': {'scoreET': 0, 'coachId': 210121, 'si...  2018-05-20 16:00:00
# 3649  {'3164': {'scoreET': 0, 'coachId': 210121, 'si...  2018-05-20 16:00:00
# 3650  {'3185': {'scoreET': 0, 'coachId': 21155, 'sid...  2018-05-20 13:00:00
# 3651  {'3185': {'scoreET': 0, 'coachId': 21155, 'sid...  2018-05-20 13:00:00
#
#                                          venue  \
# 0                             Emirates Stadium
# 1                             Emirates Stadium
# 2       The American Express Community Stadium
# 3       The American Express Community Stadium
# 4                              Stamford Bridge
# ...                                        ...
# 3647  MAPEI Stadium - Citt\u00e0 del Tricolore
# 3648
# 3649
# 3650
# 3651
#
#                                                referees score  \
# 0     [{'refereeId': 385909, 'role': 'referee'}, {'r...   4–3
# 1     [{'refereeId': 385909, 'role': 'referee'}, {'r...   4–3
# 2     [{'refereeId': 384965, 'role': 'referee'}, {'r...   0–2
# 3     [{'refereeId': 384965, 'role': 'referee'}, {'r...   0–2
# 4     [{'refereeId': 378951, 'role': 'referee'}, {'r...   2–3
# ...                                                 ...   ...
# 3647  [{'refereeId': 377255, 'role': 'referee'}, {'r...   0–1
# 3648  [{'refereeId': 377256, 'role': 'referee'}, {'r...   3–1
# 3649  [{'refereeId': 377256, 'role': 'referee'}, {'r...   3–1
# 3650  [{'refereeId': 393614, 'role': 'referee'}, {'r...   1–2
# 3651  [{'refereeId': 393614, 'role': 'referee'}, {'r...   1–2
#
#                   footedness
# 0            right-left-left
# 1     right-right-right-left
# 2     right-right-right-left
# 3          right-right-right
# 4      right-right-left-left
# ...                      ...
# 3647         right-left-left
# 3648        right-right-left
# 3649   right-right-left-left
# 3650       right-right-right
# 3651        right-right-left
#
# [3652 rows x 21 columns]

# %%
match_def.to_pickle('../data_top5/matches/match+def_lineup+footedness_ver2_top5.pkl')

# %% [markdown]
# ## Mapping Event Tags

# %%
tag_key = pd.read_csv('../data_top5/events/tags2name.csv')

# %%
k = list(zip(tag_key['Tag'], tag_key['Description']))

# %%
def unpack(x):
    x = [list(x[i].values()) for i in range(0, len(x))]
    return x

# %%
def functag2name(x):
    tag_names = list()
    for val in x:
        val = int(val)
        val_pair = [item for item in k if item[0]==val]
        tag_names.append(val_pair[0][1])
    return tag_names

# %%
events_com['tags'] = events_com['tags'].swifter.set_npartitions(8).apply(lambda x: unpack(x))
events_com['tags'] = events_com['tags'].swifter.set_npartitions(8).apply(lambda x: list(chain(*x)))
# Out:
# HBox(children=(HTML(value='Pandas Apply'), FloatProgress(value=0.0, max=2845357.0), HTML(value='')))
# HBox(children=(HTML(value='Pandas Apply'), FloatProgress(value=0.0, max=2845357.0), HTML(value='')))

# %%
events_com['tags'] = events_com['tags'].swifter.set_npartitions(8).apply(lambda x: functag2name(x))
# Out:
# HBox(children=(HTML(value='Pandas Apply'), FloatProgress(value=0.0, max=2845357.0), HTML(value='')))

# %%
#event.to_pickle('../data/events/events+players.pkl')

# %% [markdown]
# ## Converting Positions Co-ordinates

# %%
#events = pd.read_pickle('../data/events/events+players.pkl')

# %%
def clean_coordinates(x):
    x = [list(d.values()) for d in x]
    x = [l[::-1] for l in x]
    return x

# %%
events_com['positions'] = events_com['positions'].swifter.set_npartitions(8).apply(lambda x: clean_coordinates(x))
# Out:
# HBox(children=(HTML(value='Pandas Apply'), FloatProgress(value=0.0, max=2845357.0), HTML(value='')))

# %%
events_com['positions'] = events_com['positions'].swifter.set_npartitions(8).apply(lambda x: [np.multiply([-1.04, 0.68], i) for i in x])
events_com['positions'] = events_com['positions'].swifter.set_npartitions(8).apply(lambda x: [np.subtract([0, 68], i) for i in x])
# Out:
# HBox(children=(HTML(value='Pandas Apply'), FloatProgress(value=0.0, max=2845357.0), HTML(value='')))
# HBox(children=(HTML(value='Pandas Apply'), FloatProgress(value=0.0, max=2845357.0), HTML(value='')))

# %%
def roundcoords(x):
    final_roundedcoords = list()
    for l in x:
        roundedcoords = [np.round(val,decimals=2) for val in l]
        final_roundedcoords.append(roundedcoords)
    return final_roundedcoords

# %%
events_com['positions'] = events_com['positions'].apply(lambda x: roundcoords(x))

# %%
df_players = players

# %%
# Adding Roles
roles_temp = df_players['role'].values

roles = list()
for i in roles_temp:
    roles.append(i['code3'])
    

players_roles = list(zip(roles,df_players['wyId'],df_players['playerName']))

df_players_roles = pd.DataFrame(players_roles,columns = ['role','playerId','playerName1'])

df_events_roles = events_com.merge(df_players_roles, left_on = 'playerId', right_on = 'playerId')

df_events_roles.drop(['playerName1'], axis = 1, inplace = True)

df_events_roles.to_pickle('../data_top5/events/events_com.pkl')

# %% [markdown]
# # Changing Names in match_def permanently

# %%
match_def = pd.read_pickle('../data_top5/matches/match+def_lineup+footedness_ver2_top5.pkl')
player_map = pd.read_csv('../data_top5/players/PlayerMap.csv')
player_map = dict([(i,a) for i, a in zip(player_map['Lineup Name'], player_map['Wyscout Name'])])

# %%
imp = pd.DataFrame(match_def[['team', 'team_defense', 'wyId']].explode('team_defense'))
imp = imp.replace({'team_defense': player_map})
imp = pd.DataFrame(imp.groupby(['wyId', 'team'])['team_defense'].apply(list)).reset_index()

# %%
match_def = match_def.sort_values(by=['wyId', 'team']).reset_index(drop=True)
match_def['team_defense'] = imp['team_defense']

# %%
def add_posn(df):
    for i in range(0, len(df)):
        if(len(df['team_defense'][i])==4):
            df['RB'][i] = df['team_defense'][i][0]
            df['R-CB'][i] = df['team_defense'][i][1]
            df['L-CB'][i] = df['team_defense'][i][2]
            df['LB'][i] = df['team_defense'][i][3]
            df['backline'][i] = 4
        elif(len(df['team_defense'][i])==3):
            df['RCB'][i] = df['team_defense'][i][0]
            df['CB'][i] = df['team_defense'][i][1]
            df['LCB'][i] = df['team_defense'][i][2]
            df['backline'][i] = 3
        else:
            df['RWB'][i] = df['team_defense'][i][0]
            df['RCB'][i] = df['team_defense'][i][1]
            df['CB'][i] = df['team_defense'][i][2]
            df['LCB'][i] = df['team_defense'][i][3]
            df['LWB'][i] = df['team_defense'][i][4]
            df['backline'][i] = 5

# %%
add_posn(match_def)

# %%
match_def.head()
# Out:
#       wyId             team  \
# 0  2499719          Arsenal
# 1  2499719   Leicester City
# 2  2499720         Brighton
# 3  2499720  Manchester City
# 4  2499721          Burnley
#
#                                         team_defense               RB  \
# 0   [RobHolding, IgnacioMonrealEraso, SeadKolasinac]              NaN
# 1  [DannySimpson, WesMorgan, HarryMaguire, Christ...     DannySimpson
# 2  [BrunoSaltorGrau, LewisDunk, ShaneDuffy, Marku...  BrunoSaltorGrau
# 3  [VincentKompany, JohnStones, NicolasHernanOtam...              NaN
# 4  [MatthewLowton, JamesTarkowski, BenMee, Stephe...    MatthewLowton
#
#              R-CB          L-CB              LB             RCB  \
# 0             NaN           NaN             NaN      RobHolding
# 1       WesMorgan  HarryMaguire  ChristianFuchs             NaN
# 2       LewisDunk    ShaneDuffy   MarkusSuttner             NaN
# 3             NaN           NaN             NaN  VincentKompany
# 4  JamesTarkowski        BenMee     StephenWard             NaN
#
#                     CB                    LCB  RWB  LWB  backline  \
# 0  IgnacioMonrealEraso          SeadKolasinac  NaN  NaN       3.0
# 1                  NaN                    NaN  NaN  NaN       4.0
# 2                  NaN                    NaN  NaN  NaN       4.0
# 3           JohnStones  NicolasHernanOtamendi  NaN  NaN       3.0
# 4                  NaN                    NaN  NaN  NaN       4.0
#
#                       match gameweek  \
# 0    Arsenal-Leicester City        1
# 1    Arsenal-Leicester City        1
# 2  Brighton-Manchester City        1
# 3  Brighton-Manchester City        1
# 4           Chelsea-Burnley        1
#
#                                            teamsData              dateutc  \
# 0  {'1609': {'scoreET': 0, 'coachId': 7845, 'side...  2017-08-11 18:45:00
# 1  {'1609': {'scoreET': 0, 'coachId': 7845, 'side...  2017-08-11 18:45:00
# 2  {'1651': {'scoreET': 0, 'coachId': 8093, 'side...  2017-08-12 16:30:00
# 3  {'1651': {'scoreET': 0, 'coachId': 8093, 'side...  2017-08-12 16:30:00
# 4  {'1646': {'scoreET': 0, 'coachId': 8880, 'side...  2017-08-12 14:00:00
#
#                                     venue  \
# 0                        Emirates Stadium
# 1                        Emirates Stadium
# 2  The American Express Community Stadium
# 3  The American Express Community Stadium
# 4                         Stamford Bridge
#
#                                             referees score  \
# 0  [{'refereeId': 385909, 'role': 'referee'}, {'r...   4–3
# 1  [{'refereeId': 385909, 'role': 'referee'}, {'r...   4–3
# 2  [{'refereeId': 384965, 'role': 'referee'}, {'r...   0–2
# 3  [{'refereeId': 384965, 'role': 'referee'}, {'r...   0–2
# 4  [{'refereeId': 378951, 'role': 'referee'}, {'r...   2–3
#
#                footedness
# 0         right-left-left
# 1  right-right-right-left
# 2  right-right-right-left
# 3       right-right-right
# 4   right-right-left-left

# %%
match_def.to_pickle('../data_top5/matches/match+def_lineup+footedness_ver2_top5.pkl')

# %% [markdown]
# # Result

# %% [markdown]
# 1. Use **events_plot-a-match.pkl** to plot match events from same match simultaneously<br><br>
# 2. Use **events_com.pkl** to plot match events from different matches cumulatively over a season - used in all the analysis<br><br>
# 3. Use **match+def_lineup+footedness_ver2.pkl** for Defensive lineups of teams in each match from the PL 17-18 season<br><br>
# **Note:** All event coordinate data has origin on the bottom left corner of the pitch when viewed horizontally and x = [0,104], y= [0,68]
